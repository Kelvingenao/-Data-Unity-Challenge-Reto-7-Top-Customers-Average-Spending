# %%
# 📦 Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 🎯 Visual settings
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# 📥 Load the dataset
df = pd.read_csv("supermarket_sales_categories.csv")

# 🔍 Initial exploration
print(df.head())
print(df.info())
print(df.describe())

# 🧮 Total spending per customer
spending_per_customer = df.groupby("CustomerID")["TotalSales"].sum().reset_index()
spending_per_customer.columns = ["CustomerID", "TotalSpending"]
spending_per_customer = spending_per_customer.sort_values(by="TotalSpending", ascending=False)

# 📊 Top 5 customers
top_5 = spending_per_customer.head(5)
print("🏆 Top 5 Customers:\n", top_5)

# 📈 Bar chart – Top 5
sns.barplot(data=top_5, x="CustomerID", y="TotalSpending", palette="viridis")
plt.title("Top 5 Customers by Total Spending")
plt.xlabel("CustomerID")
plt.ylabel("Total Spending")
plt.tight_layout()
plt.show()

# 📉 Histogram – Spending distribution
sns.histplot(spending_per_customer["TotalSpending"], bins=30, kde=True, color="skyblue")
plt.title("Distribution of Total Spending per Customer")
plt.xlabel("Total Spending")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# 📊 Average spending
average_spending = spending_per_customer["TotalSpending"].mean()
print(f"💰 Average spending per customer: ${average_spending:.2f}")

# 🧾 Conclusion
print("\n📌 Conclusion:")
print("The top 5 customers represent a significant portion of total sales.")
print(f"The average spending per customer is ${average_spending:.2f}, which can guide segmentation and loyalty strategies.")
# Out:
#   TransactionID        Date CustomerID Category    Product  Quantity  \
# 0        T00001  2023-08-05      C0188   Snacks       Maní         7
# 1        T00002  2023-10-16      C0184  Bebidas  Coca-Cola         3
# 2        T00003  2023-07-03      C0139  Lácteos     Yogurt         3
# 3        T00004  2023-12-01      C0076   Frutas        Uva         9
# 4        T00005  2023-11-08      C0101   Carnes    Pescado         6
#
#    UnitPrice  TotalSales
# 0       1.80       12.60
# 1       1.80        5.40
# 2       1.10        3.30
# 3       1.70       15.30
# 4       6.67       40.02
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  1500 non-null   object
#  1   Date           1500 non-null   object
#  2   CustomerID     1500 non-null   object
#  3   Category       1500 non-null   object
# ...
